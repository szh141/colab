# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/colab/blob/main/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fruits = pd.DataFrame({'fruits':['strawberry', 'orange','melon'], 'weight':[20, 200, 1000],'weight2':[20, 200, 1000], 'color': ['red','orange','yellow']})
fruits
# Out:
#        fruits  weight  weight2   color
# 0  strawberry      20       20     red
# 1      orange     200      200  orange
# 2       melon    1000     1000  yellow

# %%
fruits.mean()
# Out:
# <ipython-input-6-7546d886b604>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fruits.mean()
# weight     406.666667
# weight2    406.666667
# dtype: float64

# %%
airbnb = pd.read_csv('/content/drive/MyDrive/AB_NYC_2019.csv')
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
airbnb['yearly_max'] = airbnb['price']*airbnb['availability_365']
select1 = airbnb[airbnb['yearly_max']>1]
select2 = select1[select1['yearly_max']<100000]

# %%
select1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.135400e+04  3.135400e+04  31354.000000  31354.000000  31354.000000
# mean   2.100493e+07  8.145071e+07     40.728406    -73.948753    162.091822
# std    1.148777e+07  8.673941e+07      0.056562      0.051400    254.444750
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420     10.000000
# 25%    1.167354e+07  8.619004e+06     40.688392    -73.983280     70.000000
# 50%    2.255750e+07  4.108975e+07     40.723725    -73.954115    112.000000
# 75%    3.119452e+07  1.452368e+08     40.763037    -73.930152    189.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    31354.000000       31354.000000       26147.000000
# mean         8.338426          31.849365           1.810063
# std         23.838961          51.638559           1.805657
# ...

# %%
select2.describe()
# Out:
#                  id       host_id      latitude     longitude        price  \
# count  2.986200e+04  2.986200e+04  29862.000000  29862.000000  29862.00000
# mean   2.091647e+07  8.003601e+07     40.727949    -73.947622    133.79710
# std    1.146411e+07  8.597240e+07      0.057167      0.051688    100.10683
# min    2.539000e+03  2.571000e+03     40.499790    -74.244420     10.00000
# 25%    1.158952e+07  8.455832e+06     40.687730    -73.982360     69.00000
# 50%    2.243643e+07  4.000471e+07     40.722340    -73.953070    105.00000
# 75%    3.108547e+07  1.404331e+08     40.763260    -73.928860    175.00000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990   3000.00000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    29862.000000       29862.000000       25184.000000
# mean         8.141652          32.680330           1.826229
# std         22.875515          52.260289           1.816921
# ...

# %%
select2.plot(x = 'number_of_reviews', y = 'yearly_max', kind = 'scatter', alpha = 0.01)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='yearly_max'>
