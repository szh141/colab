# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/colab/blob/main/simple_prediction_tf_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback

np.random.seed(0)
X = np.random.rand(1000, 1)
y = 40 + 30 * X + np.random.randn(1000, 1)  # Linear relation with noise

def create_model():
    model = Sequential([
        Dense(128, activation='relu', input_shape=(X.shape[1],)),
        Dense(128, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

model = create_model()

initial_weights = model.get_weights()
history = model.fit(X, y, epochs=200, verbose=0)
initial_loss = model.evaluate(X, y, verbose=0)

# %%
a = model.predict([10])
print(a)
# Out:
# 1/1 [==============================] - 0s 81ms/step
# [[338.4483]]

# %%
plt.plot(history.history['loss'], label='Model')
plt.title('Model Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

print(f"Initial loss: {initial_loss}")
# Out:
# Initial loss: 0.9674957990646362
