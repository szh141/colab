# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/colab/blob/main/inpaint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.transform import resize
from skimage import io,data
from matplotlib import pyplot as plt
import numpy as np

img1 = io.imread("/content/drive/MyDrive/Colab images/lung.png")
print(img.shape)

mask = np.zeros(img1.shape[:-1],dtype=bool)
mask[250:300, 400:600] = 1
mask[50:100, 300:433] = 1
mask[300:380, 10:120] = 1
mask[200:270, 70:95] = 1

img2 = img1*~mask[...,np.newaxis]

print('mask shape is ',mask.shape)
print('img2 shape is ',img2.shape)

fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(10,6))
ax1.imshow(img1)
ax2.imshow(img2)
ax3.imshow(mask)
# Out:
# (527, 707, 3)
# mask shape is  (527, 707)
# img2 shape is  (527, 707, 3)

# %%
from skimage.restoration import inpaint

restored_image = inpaint.inpaint_biharmonic(
    image=img2, mask = mask, channel_axis=-1
)

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(10,6))
ax1.imshow(img1)
ax2.imshow(img2)
ax3.imshow(mask)
plt.show()

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,6))
ax1.imshow(img1)
ax2.imshow(restored_image)
