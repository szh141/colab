# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/colab/blob/main/1D_FFT_on_DFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DFT vs CFT
# FFT made it easy for DFT, and its application on signal processing
#
# https://medium.com/the-modern-scientist/the-fourier-transform-and-its-application-in-machine-learning-edecfac4133c

# %%
import numpy as np
from matplotlib import pyplot as plt

# Ensure that the data is in a NumPy array or a list
time = np.arange(0, 10, 0.01)  # Time values from 0 to 10 with a step of 0.01
signal = 2 * np.sin(2 * np.pi * 1 * time) + 1 * np.sin(2 * np.pi * 2 * time)

# Plot the original time series
plt.figure(figsize=(10, 4))
plt.subplot(2, 1, 1)
plt.plot(time, signal)
plt.title('Original Time Series')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# Perform 1D Fourier Transform
fourier_transform = np.fft.fft(signal)
frequencies = np.fft.fftfreq(len(signal), 0.01)  # Frequency values (assuming a sampling interval of 0.01)

# Plot the magnitude of the Fourier Transform
fig,ax = plt.subplots(2, 1)
#magnitude plot
ax[0].plot(frequencies, np.abs(fourier_transform))

plt.title('Fourier Transform')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')

ax[1].plot(frequencies, np.abs(fourier_transform))
plt.title('Fourier Transform')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.xlim(0, 5)  # Limit the x-axis to show frequencies up to 5 Hz

plt.tight_layout()
plt.show()

# %% [markdown]
# https://numpy.org/doc/stable/reference/generated/numpy.fft.fftfreq.html

# %%
signal = np.array([-2, 8, 6, 4, 1, 0, 3, 5], dtype=float)
fourier = np.fft.fft(signal)
n = signal.size
timestep = 0.1
freq = np.fft.fftfreq(n, d=timestep)
freq
# Out:
# array([ 0.  ,  1.25,  2.5 ,  3.75, -5.  , -3.75, -2.5 , -1.25])
