# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/colab/blob/main/tnia_fft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/True-North-Intelligent-Algorithms/tnia-python/blob/030d08b426678cbf23b53276b2e515399fed9f38/notebooks/imagesc/2024_01_16_fft_vs_fft2/fft_shift.ipynb
#
# https://myuva-my.sharepoint.com/:w:/r/personal/pfa2xb_virginia_edu/_layouts/15/Doc.aspx?sourcedoc=%7B7CD1E980-91D1-4C21-906D-F7FB114AE138%7D&file=RL%20decon%20Brian%20Northern.docx&action=default&mobileredirect=true

# %%
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np
import os
from skimage import data,filters

# open scikit-image example
img = data.coins()

plt.imshow(img)

# %%
psf_2d = np.ones((25,25))
psf_2d[25//2,25//2] = 255
psf_2d = filters.gaussian(psf_2d,2)
plt.imshow(psf_2d)

# %% [markdown]
# https://numpy.org/doc/stable/reference/generated/numpy.pad.html
# check out pad width

# %%
psf_pad = np.pad(psf_2d, pad_width, 'constant')
plt.imshow(psf_pad)

# %%
print(img.shape)
print(psf_pad.shape)
# Out:
# (303, 384)
# (343, 343)

# %%
grid = np.zeros((100,100))
grid[::2,1::2] = 255
grid[1::2,::2] = 255
print(grid)
plt.imshow(grid)
# Out:
# [[  0. 255.   0. ... 255.   0. 255.]
#  [255.   0. 255. ...   0. 255.   0.]
#  [  0. 255.   0. ... 255.   0. 255.]
#  ...
#  [255.   0. 255. ...   0. 255.   0.]
#  [  0. 255.   0. ... 255.   0. 255.]
#  [255.   0. 255. ...   0. 255.   0.]]

# %%
lines = np.zeros((100,100))
lines[::2,:] = 255
print(lines)
plt.imshow(lines)
# Out:
# [[255. 255. 255. ... 255. 255. 255.]
#  [  0.   0.   0. ...   0.   0.   0.]
#  [255. 255. 255. ... 255. 255. 255.]
#  ...
#  [  0.   0.   0. ...   0.   0.   0.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [  0.   0.   0. ...   0.   0.   0.]]

# %%
test = np.fft.fft2(lines)
magnitude_fft = np.abs(test)
phase_fft = np.angle(test)

plt.imshow(magnitude_fft)
plt.colorbar()
